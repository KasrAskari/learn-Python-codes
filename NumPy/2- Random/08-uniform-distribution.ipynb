# %% [markdown]
# # Uniform Distribution
# - Used to describe probability where every event has equal chances of occuring.
#
# - E.g. Generation of random numbers.
#
# - It has three parameters:
#
#     - low - lower bound - default 0 .0.
#
#     - high - upper bound - default 1.0.
#
#     - size - The shape of the returned array.

# %%
import numpy as np
from numpy import random

# %%
x = random.uniform(size=(2,3))

print(x)
# Out:
# [[0.57125679 0.85277919 0.51769244]
#  [0.3289333  0.15158511 0.43185734]]

# %% [markdown]
# ## Visualization of Uniform Distribution

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
uniform_data = np.random.uniform(size=1000)

sns.kdeplot(uniform_data, color="blue", label="Uniform Distribution")

plt.title("Uniform Distribution", fontsize=14)
plt.xlabel("Values", fontsize=12)
plt.ylabel("Density", fontsize=12)
# plt.legend(fontsize=10)
plt.grid(alpha=0.3)
plt.show()
